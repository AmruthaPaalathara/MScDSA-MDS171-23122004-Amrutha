# %%
a=0
while a<5:
    print(a)
    a+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#break ,pass,continue
for item in range(1,10,2):
    if item ==5:
        break
    print(item)
# Out:
# 1
# 3

# %%
for item in range(1,10,2):
    if item ==5:
        pass
    print(item)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
list_ex=["Apple","Banana","Citrus","kiwi","greeen apple..`0rranfge"]
print(set(list_ex))
# Out:
# {'Apple', 'greeen apple..`0rranfge', 'kiwi', 'Banana', 'Citrus'}
