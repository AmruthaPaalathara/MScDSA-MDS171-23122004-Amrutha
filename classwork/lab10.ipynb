# %% [markdown]
# Write a python program that will read a csv file and print the mean,median,mode for a column of user choice.

# %%
def read_csv():
    with open("Customers 1.csv","r+") as file:
        content=file.readlines()
        #print(content) #print the heading of the column
        n=int(input("Enter the no.of columns: "))

        for item in content:
            items=item.split(",")
            print(items)
            for i in items:
                print(i,end="\t")
            print("\t")
    columns=[]
    user_choice=int(input("Enter the column number that the user need: "))
    for i in items:
        
        if user_choice in i.isalpha():
            columns.append(user_choice)

read_csv()
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual_Income', 'Spending_Score', 'Profession', 'Work_Experience', 'Family Size', 'Spending_Category', 'Invoice_Number\n']
# CustomerID	Gender	Age	Annual_Income	Spending_Score	Profession	Work_Experience	Family Size	Spending_Category	Invoice_Number
#
# ['1', 'Male', '19', '15000', '39', 'Healthcare', '1', '4', 'Average', '458984\n']
# 1	Male	19	15000	39	Healthcare	1	4	Average	458984
#
# ['2', 'Male', '21', '35000', '81', 'Engineer', '3', '3', 'High', '458994\n']
# 2	Male	21	35000	81	Engineer	3	3	High	458994
#
# ['3', 'Female', '20', '86000', '6', 'Engineer', '1', '1', 'Low', '458994\n']
# 3	Female	20	86000	6	Engineer	1	1	Low	458994
#
# ['4', 'Female', '23', '59000', '77', 'Lawyer', '0', '2', 'High', '458997\n']
# 4	Female	23	59000	77	Lawyer	0	2	High	458997
#
# ['5', 'Female', '31', '38000', '40', 'Entertainment', '2', '6', 'Average', '458999\n']
# 5	Female	31	38000	40	Entertainment	2	6	Average	458999
#
# ...

# %%
def f():
