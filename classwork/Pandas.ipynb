# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB 1.4 MB/s eta 0:00:08
#      --------------------------------------- 0.0/10.7 MB 281.8 kB/s eta 0:00:38
#      --------------------------------------- 0.1/10.7 MB 409.6 kB/s eta 0:00:26
#      --------------------------------------- 0.1/10.7 MB 328.8 kB/s eta 0:00:33
#      --------------------------------------- 0.1/10.7 MB 375.8 kB/s eta 0:00:29
#      --------------------------------------- 0.1/10.7 MB 375.8 kB/s eta 0:00:29
# ...

# %%
import pandas as pd #help to manipulate data and also use to retrieve data

# %%
students = {
    "Name":["Arnav","Kushi","Nirmal","Anjali","Rohan","Beena","Krithi"],
    "Age":[12,15,18,19,25,21,26]
}

# %%
print(students)
# Out:
# {'Name': ['Arnav', 'Kushi', 'Nirmal', 'Anjali', 'Rohan', 'Beena', 'Krithi'], 'Age': [12, 15, 18, 19, 25, 21, 26]}

# %%
df=pd.DataFrame(students) #dataFrame is a function under pandas where it has many operations. One such operation is head

# %%
print(df.head())  # df.function() only works in .ipynb file. To work in py file we need to give print function
# Out:
#      Name  Age
# 0   Arnav   12
# 1   Kushi   15
# 2  Nirmal   18
# 3  Anjali   19
# 4   Rohan   25

# %%
df.head()  #print first 5 rows incl the heading
# Out:
#      Name  Age
# 0   Arnav   12
# 1   Kushi   15
# 2  Nirmal   18
# 3  Anjali   19
# 4   Rohan   25

# %%
df.tail() #print last 5 rows
# Out:
#      Name  Age
# 2  Nirmal   18
# 3  Anjali   19
# 4   Rohan   25
# 5   Beena   21
# 6  Krithi   26

# %%
df=pd.read_csv("Customers 1.csv")

# %%
df.head(3)  #print first 3 columns of the dataset. specify how much rows we need
# Out:
#    CustomerID  Gender  Age  Annual_Income  Spending_Score  Profession  \
# 0           1    Male   19          15000              39  Healthcare
# 1           2    Male   21          35000              81    Engineer
# 2           3  Female   20          86000               6    Engineer
#
#    Work_Experience  Family Size Spending_Category  Invoice_Number
# 0                1            4           Average          458984
# 1                3            3              High          458994
# 2                1            1               Low          458994

# %%
df.tail(8)
# Out:
#       CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 1992        1993    Male   94         181183              24      Marketing
# 1993        1994  Female   64         175254             100         Artist
# 1994        1995  Female   19          54121              89       Engineer
# 1995        1996  Female   71         184387              40         Artist
# 1996        1997  Female   91          73158              32         Doctor
# 1997        1998    Male   87          90961              14     Healthcare
# 1998        1999    Male   77         182109               4      Executive
# 1999        2000    Male   90         110610              52  Entertainment
#
#       Work_Experience  Family Size Spending_Category  Invoice_Number
# 1992                9            3           Average          461760
# 1993                9            5              High          461760
# 1994                6            3              High          461762
# ...

# %%
df.columns #dtype means data type and object means string
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual_Income', 'Spending_Score',
#        'Profession', 'Work_Experience', 'Family Size', 'Spending_Category',
#        'Invoice_Number'],
#       dtype='object')

# %%
df.describe() #shows standard devaition,maximum number,mean and every minute details
# Out:
#         CustomerID          Age  Annual_Income  Spending_Score  \
# count  2000.000000  2000.000000    2000.000000     2000.000000
# mean   1000.500000    48.960000  110731.821500       50.962500
# std     577.494589    28.429747   45739.536688       27.934661
# min       1.000000     0.000000       0.000000        0.000000
# 25%     500.750000    25.000000   74572.000000       28.000000
# 50%    1000.500000    48.000000  110045.000000       50.000000
# 75%    1500.250000    73.000000  149092.750000       75.000000
# max    2000.000000    99.000000  189974.000000      100.000000
#
#        Work_Experience  Family Size  Invoice_Number
# count      2000.000000  2000.000000     2000.000000
# mean          4.102500     3.768500   461389.611000
# std           3.922204     1.970749     1529.636635
# min           0.000000     1.000000   458984.000000
# 25%           1.000000     2.000000   459890.500000
# 50%           3.000000     4.000000   461425.000000
# ...

# %%
df[["Age","Spending_Score"]]
# Out:
#       Age  Spending_Score
# 0      19              39
# 1      21              81
# 2      20               6
# 3      23              77
# 4      31              40
# ...   ...             ...
# 1995   71              40
# 1996   91              32
# 1997   87              14
# 1998   77               4
# 1999   90              52
#
# [2000 rows x 2 columns]

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.6 MB 1.3 MB/s eta 0:00:06
#      ---------------------------------------- 0.1/7.6 MB 1.1 MB/s eta 0:00:07
#       --------------------------------------- 0.1/7.6 MB 1.1 MB/s eta 0:00:08
#      - -------------------------------------- 0.2/7.6 MB 1.3 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/7.6 MB 1.1 MB/s eta 0:00:07
#      - -------------------------------------- 0.3/7.6 MB 1.2 MB/s eta 0:00:07
#      - -------------------------------------- 0.3/7.6 MB 1.0 MB/s eta 0:00:07
#      -- ------------------------------------- 0.4/7.6 MB 1.1 MB/s eta 0:00:07
#      -- ------------------------------------- 0.5/7.6 MB 1.2 MB/s eta 0:00:07
#      --- ------------------------------------ 0.6/7.6 MB 1.3 MB/s eta 0:00:06
#      --- ------------------------------------ 0.6/7.6 MB 1.2 MB/s eta 0:00:06
# ...

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
:/'
:::::::::::::::::::::::::::::::::::'
# Out:
#   Cell In[49], line 1
#     :/'
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
:
# Out:
#   Cell In[50], line 1
#     :
#     ^
# SyntaxError: invalid syntax

# %%
::
# Out:
#   Cell In[51], line 1
#     ::
#     ^
# SyntaxError: invalid syntax

# %%
:
# Out:
#   Cell In[52], line 1
#     :
#     ^
# SyntaxError: invalid syntax

# %%
::
# Out:
#   Cell In[53], line 1
#     ::
#     ^
# SyntaxError: invalid syntax

# %%
:''
# Out:
#   Cell In[54], line 1
#     :''
#     ^
# SyntaxError: invalid syntax

# %%
::
# Out:
#   Cell In[55], line 1
#     ::
#     ^
# SyntaxError: invalid syntax

# %%
''
# Out:
# ''

# %%
/''
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Github\MScDSA-MDS171-23122004-Amrutha\Pandas.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github/MScDSA-MDS171-23122004-Amrutha/Pandas.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> ''()
#
# ...

# %%
/''
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Github\MScDSA-MDS171-23122004-Amrutha\Pandas.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github/MScDSA-MDS171-23122004-Amrutha/Pandas.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> ''()
#
# ...

# %%
''
# Out:
# ''

# %%
/''
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5104\1733298515.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   ''()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Github\MScDSA-MDS171-23122004-Amrutha\Pandas.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Github/MScDSA-MDS171-23122004-Amrutha/Pandas.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> ''()
#
# ...

# %%
''
# Out:
# ''

# %%
/''
